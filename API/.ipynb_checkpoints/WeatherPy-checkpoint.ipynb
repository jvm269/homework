# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Trends
#
# -temperatures are higher closer to the Equator (at 0° Latitude) and are much lower in the Northern Hemishpere, at this time of year in February.
#
# -no correlation between humidity and Latitude as well as with cloudiness and Latitude
#
# -wind speeds increase in the upper and lower halves on the hemisphere,

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json as json

# Import API key
from api_key import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Get Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -73.83,
#         "lat": -41.87
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 44.6,
#         "pressure": 1016,
#         "humidity": 87,
#         "temp_min": 44.6,
#         "temp_max": 44.6
#     },
#     "visibility": 3300,
#     "wind": {
#         "speed": 5.82,
#         "deg": 310
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1559866431,
#     "sys": {
#         "type": 1,
#         "id": 8512,
#         "message": 0.0049,
#         "country": "CL",
#         "sunrise": 1559823405,
#         "sunset": 1559856688
#     },
#     "timezone": -14400,
#     "id": 3899695,
#     "name": "Ancud",
#     "cod": 200
# }

# %%
print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Set Up Lists to Hold Reponse Info
city_name = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Mogadishu
# Processing Record 2 | Mar del Plata
# City not found. Skipping...
# Processing Record 3 | Yellowknife
# Processing Record 4 | Batemans Bay
# Processing Record 5 | Punta Arenas
# Processing Record 6 | Houma
# Processing Record 7 | Kirakira
# City not found. Skipping...
# Processing Record 8 | Ushuaia
# City not found. Skipping...
# Processing Record 9 | Georgetown
# Processing Record 10 | Gazojak
# Processing Record 11 | Tuatapere
# City not found. Skipping...
# Processing Record 12 | Grand Gaube
# Processing Record 13 | Albany
# Processing Record 14 | Faanui
# Processing Record 15 | Yekimovichi
# Processing Record 16 | Sinnamary
# Processing Record 17 | Mataura
# Processing Record 18 | Busselton
# Processing Record 19 | Chuy
# Processing Record 20 | Chokurdakh
# Processing Record 21 | Meulaboh
# Processing Record 22 | Zavitinsk
# Processing Record 23 | Swedru
# Processing Record 24 | Abu Samrah
# Processing Record 25 | Castro
# Processing Record 26 | Cape Town
# Processing Record 27 | Cherskiy
# Processing Record 28 | Port Blair
# Processing Record 29 | Nikolskoye
# City not found. Skipping...
# Processing Record 30 | Avarua
# Processing Record 31 | Provideniya
# City not found. Skipping...
# Processing Record 32 | Saint George
# Processing Record 33 | Vaini
# Processing Record 34 | Erzin
# City not found. Skipping...
# Processing Record 35 | Saskylakh
# Processing Record 36 | Kruisfontein
# Processing Record 37 | Hermanus
# Processing Record 38 | Quzhou
# Processing Record 39 | Barrow
# Processing Record 40 | Togur
# Processing Record 41 | Rikitea
# Processing Record 42 | Safidon
# Processing Record 43 | Nanortalik
# Processing Record 44 | Sorland
# City not found. Skipping...
# Processing Record 45 | Masterton
# Processing Record 46 | East London
# Processing Record 47 | Chapais
# Processing Record 48 | Moura
# Processing Record 49 | Tiksi
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 | Neuquen
# City not found. Skipping...
# Processing Record 51 | Tasiilaq
# Processing Record 52 | Mmabatho
# Processing Record 53 | Hithadhoo
# Processing Record 54 | Bara
# Processing Record 55 | Colac
# Processing Record 56 | Naze
# Processing Record 57 | Okhotsk
# Processing Record 58 | Puerto Ayora
# Processing Record 59 | Saint-Philippe
# Processing Record 60 | Dwarka
# Processing Record 61 | Clyde River
# Processing Record 62 | Licata
# Processing Record 63 | Atar
# Processing Record 64 | Pevek
# City not found. Skipping...
# Processing Record 65 | Airai
# Processing Record 66 | Hilo
# Processing Record 67 | Kodiak
# Processing Record 68 | Joniskis
# Processing Record 69 | Qaanaaq
# Processing Record 70 | Dunedin
# Processing Record 71 | Cockburn Town
# Processing Record 72 | Butaritari
# Processing Record 73 | Kapaa
# Processing Record 74 | Severo-Kurilsk
# Processing Record 75 | Souillac
# Processing Record 76 | Vila Velha
# Processing Record 77 | Chiang Khong
# Processing Record 78 | Plymouth
# Processing Record 79 | New Norfolk
# Processing Record 80 | Kodinsk
# Processing Record 81 | Portland
# Processing Record 82 | Spencer
# Processing Record 83 | Bluff
# Processing Record 84 | Itarema
# Processing Record 85 | Ilulissat
# Processing Record 86 | Jamestown
# Processing Record 87 | Lompoc
# Processing Record 88 | Terney
# City not found. Skipping...
# Processing Record 89 | Henties Bay
# Processing Record 90 | Pesqueira
# Processing Record 91 | Nabire
# Processing Record 92 | Benguela
# Processing Record 93 | Tuktoyaktuk
# Processing Record 94 | Spearfish
# Processing Record 95 | Viedma
# Processing Record 96 | Atuona
# City not found. Skipping...
# Processing Record 97 | Matamoros
# City not found. Skipping...
# Processing Record 98 | Ambilobe
# Processing Record 99 | Dolores
# Processing Record 100 | Metro
# Processing Record 101 | Durban
# Processing Record 102 | Balkanabat
# Processing Record 103 | Bad Neuenahr-Ahrweiler
# Processing Record 104 | Alta
# Processing Record 105 | Kirkland Lake
# Processing Record 106 | Palmas de Monte Alto
# Processing Record 107 | Mettupalayam
# Processing Record 108 | Hasaki
# Processing Record 109 | Lazaro Cardenas
# City not found. Skipping...
# Processing Record 110 | Mahibadhoo
# Processing Record 111 | Alekseyevka
# Processing Record 112 | Maceio
# Processing Record 113 | Narsaq
# Processing Record 114 | Lebu
# Processing Record 115 | Ribeira Grande
# Processing Record 116 | Grenada
# Processing Record 117 | Esperance
# Processing Record 118 | San Patricio
# Processing Record 119 | Sao Joao da Barra
# Processing Record 120 | Fort Nelson
# Processing Record 121 | Orlik
# Processing Record 122 | Noumea
# City not found. Skipping...
# Processing Record 123 | Khatanga
# Processing Record 124 | Ishigaki
# Processing Record 125 | Port Alfred
# Processing Record 126 | Bredasdorp
# City not found. Skipping...
# Processing Record 127 | Axim
# Processing Record 128 | Vao
# Processing Record 129 | Arraial do Cabo
# Processing Record 130 | Upernavik
# Processing Record 131 | Kieta
# City not found. Skipping...
# Processing Record 132 | Luderitz
# Processing Record 133 | Acari
# Processing Record 134 | La Ronge
# Processing Record 135 | Talnakh
# Processing Record 136 | Presque Isle
# Processing Record 137 | Vostok
# Processing Record 138 | Margate
# Processing Record 139 | Chulman
# Processing Record 140 | Jijiga
# City not found. Skipping...
# Processing Record 141 | Haridwar
# Processing Record 142 | Labuhan
# Processing Record 143 | Cidreira
# Processing Record 144 | Belyy Yar
# Processing Record 145 | Thompson
# Processing Record 146 | Bilibino
# Processing Record 147 | Victoria
# Processing Record 148 | Frontera
# City not found. Skipping...
# Processing Record 149 | Zelenoborskiy
# Processing Record 150 | Kaitangata
# Processing Record 151 | Dosso
# Processing Record 152 | Kavieng
# Processing Record 153 | Mahebourg
# Processing Record 154 | Timaru
# Processing Record 155 | Goure
# Processing Record 156 | Hambantota
# City not found. Skipping...
# Processing Record 157 | Miles City
# City not found. Skipping...
# Processing Record 158 | Merauke
# Processing Record 159 | Dikson
# Processing Record 160 | Torbay
# Processing Record 161 | Pahalgam
# City not found. Skipping...
# Processing Record 162 | Dingle
# Processing Record 163 | Conde
# Processing Record 164 | Riyadh
# Processing Record 165 | Karratha
# Processing Record 166 | Burnie
# Processing Record 167 | Namibe
# Processing Record 168 | Petropavlovsk-Kamchatskiy
# Processing Record 169 | Fort-Shevchenko
# Processing Record 170 | Longyearbyen
# City not found. Skipping...
# Processing Record 171 | Ahipara
# Processing Record 172 | Port Hawkesbury
# Processing Record 173 | Meadow Lake
# Processing Record 174 | Nouadhibou
# Processing Record 175 | Lavrentiya
# Processing Record 176 | Juybar
# Processing Record 177 | Samarai
# Processing Record 178 | Tianpeng
# City not found. Skipping...
# Processing Record 179 | Port Lincoln
# Processing Record 180 | Morgan City
# Processing Record 181 | Zumarraga
# Processing Record 182 | Flinders
# Processing Record 183 | Hamilton
# Processing Record 184 | Puerto El Triunfo
# Processing Record 185 | Veseloyarsk
# Processing Record 186 | Codrington
# Processing Record 187 | Aitape
# Processing Record 188 | Tommot
# Processing Record 189 | Lagoa
# Processing Record 190 | Kingman
# Processing Record 191 | Soe
# Processing Record 192 | Saldanha
# Processing Record 193 | Bay Roberts
# Processing Record 194 | Marapanim
# Processing Record 195 | Hulst
# Processing Record 196 | Champerico
# Processing Record 197 | Mandera
# Processing Record 198 | Hobart
# Processing Record 199 | Srednekolymsk
# Processing Record 200 | Port Elizabeth
# Processing Record 201 | Yumen
# Processing Record 202 | Egvekinot
# Processing Record 203 | Novoagansk
# Processing Record 204 | Lorengau
# Processing Record 205 | Alofi
# Processing Record 206 | Parrita
# Processing Record 207 | Ketchikan
# Processing Record 208 | Gat
# Processing Record 209 | Rawson
# Processing Record 210 | Te Anau
# Processing Record 211 | Walvis Bay
# Processing Record 212 | Abu Dhabi
# Processing Record 213 | Buenos Aires
# Processing Record 214 | Quesnel
# City not found. Skipping...
# Processing Record 215 | Hami
# Processing Record 216 | Boende
# Processing Record 217 | Alekseyevsk
# Processing Record 218 | Chicama
# Processing Record 219 | Glenwood Springs
# Processing Record 220 | Olga
# Processing Record 221 | Rome
# Processing Record 222 | Sao Filipe
# Processing Record 223 | Zyryanka
# Processing Record 224 | Robe
# City not found. Skipping...
# Processing Record 225 | Anadyr
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 226 | College
# Processing Record 227 | Honningsvag
# Processing Record 228 | Basco
# Processing Record 229 | Port Hedland
# Processing Record 230 | La Libertad
# Processing Record 231 | San Cristobal
# Processing Record 232 | San Luis
# Processing Record 233 | Guerrero Negro
# Processing Record 234 | Cabo San Lucas
# Processing Record 235 | Jackville
# Processing Record 236 | Mackenzie
# Processing Record 237 | Nizhniy Tsasuchey
# City not found. Skipping...
# Processing Record 238 | Leh
# Processing Record 239 | Calabozo
# Processing Record 240 | Faribault
# Processing Record 241 | Tadine
# Processing Record 242 | Tshikapa
# City not found. Skipping...
# Processing Record 243 | Hobyo
# Processing Record 244 | Saint-Augustin
# Processing Record 245 | Normandin
# Processing Record 246 | Borogontsy
# Processing Record 247 | Salinas
# City not found. Skipping...
# Processing Record 248 | Bethel
# City not found. Skipping...
# Processing Record 249 | Miandrivazo
# Processing Record 250 | Mazamari
# City not found. Skipping...
# Processing Record 251 | Karpogory
# Processing Record 252 | Hualmay
# Processing Record 253 | Fortuna
# Processing Record 254 | Copiapo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 255 | Barreirinhas
# Processing Record 256 | Palu
# Processing Record 257 | Lakes Entrance
# Processing Record 258 | Miramar
# Processing Record 259 | Iraquara
# Processing Record 260 | Pont-Rouge
# Processing Record 261 | Kununurra
# City not found. Skipping...
# Processing Record 262 | Taitung
# Processing Record 263 | Bukama
# Processing Record 264 | Marshfield
# Processing Record 265 | Vila Franca do Campo
# Processing Record 266 | Broome
# Processing Record 267 | Geraldton
# City not found. Skipping...
# Processing Record 268 | Acajutla
# Processing Record 269 | Bahia Blanca
# Processing Record 270 | Humaita
# Processing Record 271 | Abay
# Processing Record 272 | Puerto Narino
# Processing Record 273 | Goderich
# Processing Record 274 | Rio Gallegos
# Processing Record 275 | Inuvik
# Processing Record 276 | Norman Wells
# Processing Record 277 | Bonthe
# Processing Record 278 | Bella Union
# Processing Record 279 | Northfield
# Processing Record 280 | Brownwood
# Processing Record 281 | Salalah
# Processing Record 282 | Vardo
# Processing Record 283 | Quelimane
# Processing Record 284 | Nieuw Amsterdam
# Processing Record 285 | Bathsheba
# Processing Record 286 | Iqaluit
# Processing Record 287 | Tawang
# City not found. Skipping...
# Processing Record 288 | Union
# Processing Record 289 | Tilichiki
# Processing Record 290 | Albanel
# City not found. Skipping...
# Processing Record 291 | Bourg-en-Bresse
# Processing Record 292 | Camacha
# Processing Record 293 | Las Cruces
# Processing Record 294 | Ancud
# City not found. Skipping...
# Processing Record 295 | Xai-Xai
# Processing Record 296 | Colares
# Processing Record 297 | Takoradi
# Processing Record 298 | Shelburne
# Processing Record 299 | Rochester
# Processing Record 300 | Dawlatabad
# Processing Record 301 | Darovskoy
# Processing Record 302 | Jipijapa
# City not found. Skipping...
# Processing Record 303 | Mangrol
# Processing Record 304 | San Jose
# Processing Record 305 | Kerman
# Processing Record 306 | Martinho Campos
# Processing Record 307 | Ekhabi
# Processing Record 308 | Muros
# Processing Record 309 | Shirochanka
# Processing Record 310 | Pangnirtung
# Processing Record 311 | Vestmannaeyjar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 312 | Abu Zabad
# Processing Record 313 | Anaconda
# Processing Record 314 | Sitka
# Processing Record 315 | Fare
# Processing Record 316 | Ponta do Sol
# Processing Record 317 | Luena
# Processing Record 318 | Huron
# Processing Record 319 | Cairns
# City not found. Skipping...
# Processing Record 320 | Mount Pleasant
# Processing Record 321 | Pochutla
# Processing Record 322 | Cabedelo
# Processing Record 323 | Yeppoon
# Processing Record 324 | Havre-Saint-Pierre
# Processing Record 325 | Amapa
# Processing Record 326 | La Teste-de-Buch
# Processing Record 327 | Tongren
# Processing Record 328 | Mitsamiouli
# City not found. Skipping...
# Processing Record 329 | Wattegama
# Processing Record 330 | Outjo
# Processing Record 331 | Mersin
# Processing Record 332 | Sorong
# Processing Record 333 | Bloemfontein
# Processing Record 334 | Lusaka
# Processing Record 335 | Harrisburg
# Processing Record 336 | Lebedyn
# Processing Record 337 | Mobaye
# Processing Record 338 | Quatre Cocos
# Processing Record 339 | Baykit
# Processing Record 340 | The Valley
# Processing Record 341 | Yerbogachen
# Processing Record 342 | Sovetskiy
# City not found. Skipping...
# Processing Record 343 | Mehamn
# Processing Record 344 | Aripuana
# Processing Record 345 | Port Hardy
# Processing Record 346 | Zhangye
# Processing Record 347 | Steinfurt
# Processing Record 348 | Rio Grande
# City not found. Skipping...
# Processing Record 349 | Mount Gambier
# Processing Record 350 | Cayenne
# Processing Record 351 | Komsomolskiy
# City not found. Skipping...
# Processing Record 352 | Uray
# Processing Record 353 | Harper
# Processing Record 354 | Daru
# Processing Record 355 | Ulladulla
# Processing Record 356 | Tooele
# Processing Record 357 | Grootfontein
# Processing Record 358 | Kouango
# Processing Record 359 | Taoudenni
# Processing Record 360 | Nanchang
# Processing Record 361 | Malpe
# Processing Record 362 | Tura
# Processing Record 363 | Karakol
# City not found. Skipping...
# Processing Record 364 | Matiri
# Processing Record 365 | Teguise
# Processing Record 366 | Monroe
# Processing Record 367 | Taltal
# City not found. Skipping...
# Processing Record 368 | Buchanan
# Processing Record 369 | Perth
# Processing Record 370 | Maniitsoq
# Processing Record 371 | Carnarvon
# Processing Record 372 | Minas
# Processing Record 373 | Bandarbeyla
# Processing Record 374 | Conselheiro Pena
# Processing Record 375 | Beringovskiy
# Processing Record 376 | Sheregesh
# Processing Record 377 | Gallup
# Processing Record 378 | Kita
# Processing Record 379 | Lamu
# Processing Record 380 | La Union
# Processing Record 381 | Koutsouras
# Processing Record 382 | Sao Geraldo do Araguaia
# Processing Record 383 | Dong Hoi
# Processing Record 384 | Pushkino
# Processing Record 385 | Los Llanos de Aridane
# Processing Record 386 | Wuwei
# Processing Record 387 | Vanimo
# Processing Record 388 | Padang
# Processing Record 389 | Guaira
# Processing Record 390 | Sioux Lookout
# Processing Record 391 | Tagusao
# Processing Record 392 | Vilcun
# Processing Record 393 | Oume
# City not found. Skipping...
# Processing Record 394 | Roura
# Processing Record 395 | Kurilsk
# Processing Record 396 | Necochea
# Processing Record 397 | Raudeberg
# City not found. Skipping...
# Processing Record 398 | Faya
# Processing Record 399 | Whitehorse
# Processing Record 400 | Isangel
# City not found. Skipping...
# Processing Record 401 | Le Port
# Processing Record 402 | Wanning
# City not found. Skipping...
# Processing Record 403 | Vryburg
# Processing Record 404 | Solnechnyy
# Processing Record 405 | Aykhal
# Processing Record 406 | Hokitika
# City not found. Skipping...
# Processing Record 407 | Jinchang
# Processing Record 408 | Aksu
# Processing Record 409 | Marfino
# Processing Record 410 | Kharitonovo
# Processing Record 411 | Progreso
# Processing Record 412 | Moses Lake
# Processing Record 413 | Tucuman
# Processing Record 414 | Tarko-Sale
# Processing Record 415 | Plouzane
# Processing Record 416 | Salta
# Processing Record 417 | Iranshahr
# Processing Record 418 | Sebezh
# Processing Record 419 | Tezu
# Processing Record 420 | Omboue
# Processing Record 421 | Mao
# Processing Record 422 | Turbat
# Processing Record 423 | Hirado
# City not found. Skipping...
# Processing Record 424 | Tessalit
# Processing Record 425 | Teya
# Processing Record 426 | Sinnai
# Processing Record 427 | Rocky Mountain House
# Processing Record 428 | Acaponeta
# City not found. Skipping...
# Processing Record 429 | Norton
# Processing Record 430 | Laguna
# Processing Record 431 | Coquimbo
# Processing Record 432 | Kasongo
# Processing Record 433 | Machilipatnam
# Processing Record 434 | Luganville
# Processing Record 435 | Yen Bai
# City not found. Skipping...
# Processing Record 436 | Nome
# Processing Record 437 | Husavik
# Processing Record 438 | Mazyr
# Processing Record 439 | Jalu
# Processing Record 440 | Aykino
# Processing Record 441 | Guaimaro
# Processing Record 442 | Martapura
# City not found. Skipping...
# Processing Record 443 | Eskil
# Processing Record 444 | Peniche
# Processing Record 445 | Suzdal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 446 | Road Town
# Processing Record 447 | Yenagoa
# Processing Record 448 | Voznesenye
# Processing Record 449 | Tual
# Processing Record 450 | Rocha
# Processing Record 451 | Ixtapa
# Processing Record 452 | Rock Sound
# Processing Record 453 | Pisco
# City not found. Skipping...
# Processing Record 454 | Praia da Vitoria
# Processing Record 455 | Alindao
# Processing Record 456 | Cradock
# Processing Record 457 | Lillesand
# Processing Record 458 | Aklavik
# Processing Record 459 | Zhuanghe
# Processing Record 460 | Kawalu
# Processing Record 461 | Vazante
# Processing Record 462 | Spijkenisse
# Processing Record 463 | Kupang
# Processing Record 464 | Katsuura
# City not found. Skipping...
# Processing Record 465 | Ayagoz
# Processing Record 466 | Mishkino
# City not found. Skipping...
# Processing Record 467 | Ballina
# Processing Record 468 | Trojes
# Processing Record 469 | Sabang
# Processing Record 470 | Haines Junction
# Processing Record 471 | Saint Anthony
# Processing Record 472 | Felipe Carrillo Puerto
# Processing Record 473 | Kerrville
# City not found. Skipping...
# Processing Record 474 | Belmonte
# Processing Record 475 | Usinsk
# Processing Record 476 | Itupiranga
# Processing Record 477 | Milkovo
# Processing Record 478 | Funtua
# Processing Record 479 | Timbuktu
# Processing Record 480 | Biltine
# Processing Record 481 | Yoichi
# Processing Record 482 | Sabya
# Processing Record 483 | Kudahuvadhoo
# Processing Record 484 | Minab
# Processing Record 485 | Mandan
# Processing Record 486 | Umm Lajj
# Processing Record 487 | Van Buren
# Processing Record 488 | Nemuro
# Processing Record 489 | Nortelandia
# Processing Record 490 | Touros
# Processing Record 491 | Jumla
# Processing Record 492 | La Rioja
# Processing Record 493 | Mizdah
# City not found. Skipping...
# Processing Record 494 | Mount Isa
# Processing Record 495 | Sur
# Processing Record 496 | Zhigansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 497 | Ostrovnoy
# Processing Record 498 | Seoul
# Processing Record 499 | Palanga
# Processing Record 500 | Marzuq
# Processing Record 501 | Matara
# Processing Record 502 | Zeya
# Processing Record 503 | Ozinki
# Processing Record 504 | Ulagan
# Processing Record 505 | Juneau
# Processing Record 506 | Natal
# Processing Record 507 | Klaksvik
# Processing Record 508 | Bambous Virieux
# Processing Record 509 | Muli
# Processing Record 510 | Rincon
# Processing Record 511 | Burgos
# City not found. Skipping...
# Processing Record 512 | Ojinaga
# Processing Record 513 | Coalinga
# Processing Record 514 | Carballo
# Processing Record 515 | Boa Vista
# Processing Record 516 | Tazovskiy
# Processing Record 517 | Taicheng
# Processing Record 518 | Inirida
# City not found. Skipping...
# Processing Record 519 | Tibagi
# Processing Record 520 | Marsaxlokk
# Processing Record 521 | Kathu
# City not found. Skipping...
# Processing Record 522 | Phatthalung
# Processing Record 523 | Kirundo
# Processing Record 524 | Russell
# Processing Record 525 | Rurrenabaque
# Processing Record 526 | Buraydah
# Processing Record 527 | Payson
# City not found. Skipping...
# Processing Record 528 | Iskandar
# City not found. Skipping...
# Processing Record 529 | Goba
# Processing Record 530 | Ankara
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame from Cities, Latitude, Longitude, Temperature, Humidity, Cloudiness & Wind Speed
weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               530
# Country            530
# Date               530
# Latitude           530
# Longitude          530
# Max Temperature    530
# Humidity           530
# Cloudiness         530
# Wind Speed         530
# dtype: int64

# %%
# Display DataFrame
weather_data.head()
# Out:
#             City Country        Date  Latitude  Longitude  Max Temperature  \
# 0      Mogadishu      SO  1559866438      2.04      45.34            77.09
# 1  Mar del Plata      AR  1559866438    -46.43     -67.52            45.77
# 2    Yellowknife      CA  1559866393     62.45    -114.38            41.00
# 3   Batemans Bay      AU  1559866439    -35.71     150.18            55.99
# 4   Punta Arenas      CL  1559866439    -53.16     -70.91            39.20
#
#    Humidity  Cloudiness  Wind Speed
# 0        86           3       10.83
# 1        55          45       21.56
# 2        86          90       12.75
# 3        65           0        3.00
# 4        86          40        9.17

# %%
# Export & Save Data Into a .csv.
weather_data.to_csv("weather_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="red", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Max Temperature (02/01/2019)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build Scatter Plot for Each Data Type
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="red", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Max Temperature (02/01/2019)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Cloudiness (02/01/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("City_Latitude_vs_Cloudiness.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Wind Speed (02/01/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("City_Latitude_vs_Wind_Speed.png")

# Show Plot
plt.show()
